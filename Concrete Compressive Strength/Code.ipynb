# %% [markdown]
# Concrete Compressive Strength ML Model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dataset = pd.read_csv('C:\Windows\concrete_data2.csv')

# %%
dataset
# Out:
#      cement  blast_furnace_slag  fly_ash  water  superplasticizer  \
# 0     540.0                 0.0      0.0  162.0               2.5
# 1     540.0                 0.0      0.0  162.0               2.5
# 2     332.5               142.5      0.0  228.0               0.0
# 3     332.5               142.5      0.0  228.0               0.0
# 4     198.6               132.4      0.0  192.0               0.0
# ..      ...                 ...      ...    ...               ...
# 824   276.4               116.0     90.3  179.6               8.9
# 825   322.2                 0.0    115.6  196.0              10.4
# 826   148.5               139.4    108.6  192.7               6.1
# 827   159.1               186.7      0.0  175.6              11.3
# 828   260.9               100.5     78.3  200.6               8.6
#
#      coarse_aggregate  fine_aggregate   age  concrete_compressive_strength
# 0              1040.0            676.0   28                          79.99
# ...

# %%
dataset.head()
# Out:
#    cement  blast_furnace_slag  fly_ash  water  superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    coarse_aggregate  fine_aggregate   age  concrete_compressive_strength
# 0            1040.0            676.0   28                          79.99
# 1            1055.0            676.0   28                          61.89
# 2             932.0            594.0  270                          40.27
# 3             932.0            594.0  365                          41.05
# 4             978.4            825.5  360                          44.30

# %%
dataset.tail()
# Out:
#      cement  blast_furnace_slag  fly_ash  water  superplasticizer  \
# 824   276.4               116.0     90.3  179.6               8.9
# 825   322.2                 0.0    115.6  196.0              10.4
# 826   148.5               139.4    108.6  192.7               6.1
# 827   159.1               186.7      0.0  175.6              11.3
# 828   260.9               100.5     78.3  200.6               8.6
#
#      coarse_aggregate  fine_aggregate   age  concrete_compressive_strength
# 824             870.1            768.3   28                          44.28
# 825             817.9            813.4   28                          31.18
# 826             892.4            780.0   28                          23.70
# 827             989.6            788.9   28                          32.77
# 828             864.5            761.5   28                          32.40

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 829 entries, 0 to 828
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   cement                         829 non-null    float64
#  1   blast_furnace_slag             829 non-null    float64
#  2   fly_ash                        829 non-null    float64
#  3   water                          829 non-null    float64
#  4   superplasticizer               829 non-null    float64
#  5   coarse_aggregate               829 non-null    float64
#  6   fine_aggregate                 829 non-null    float64
#  7   age                            829 non-null    int64
#  8   concrete_compressive_strength  829 non-null    float64
# dtypes: float64(8), int64(1)
# memory usage: 58.4 KB

# %%
dataset.describe()
# Out:
#            cement  blast_furnace_slag     fly_ash       water  \
# count  829.000000          829.000000  829.000000  829.000000
# mean   288.758745           87.780338   42.111580  184.883233
# std    108.904670           89.302235   61.839298   20.781305
# min    102.000000            0.000000    0.000000  126.600000
# 25%    190.000000            0.000000    0.000000  171.200000
# 50%    295.000000           93.400000    0.000000  186.000000
# 75%    362.600000          162.400000   97.000000  194.000000
# max    540.000000          359.400000  200.100000  247.000000
#
#        superplasticizer  coarse_aggregate  fine_aggregate          age  \
# count        829.000000        829.000000       829.000000  829.000000
# mean           5.652955        959.525090       767.069481   47.208685
# std            6.322400         76.241764        83.297292   68.383712
# min            0.000000        801.000000       594.000000    1.000000
# ...

# %%
dataset.dtypes
# Out:
# cement                           float64
# blast_furnace_slag               float64
# fly_ash                          float64
# water                            float64
# superplasticizer                 float64
# coarse_aggregate                 float64
# fine_aggregate                   float64
# age                                int64
# concrete_compressive_strength    float64
# dtype: object

# %%
dataset.isnull().sum()
# Out:
# cement                           0
# blast_furnace_slag               0
# fly_ash                          0
# water                            0
# superplasticizer                 0
# coarse_aggregate                 0
# fine_aggregate                   0
# age                              0
# concrete_compressive_strength    0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 829 entries, 0 to 828
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   cement                         829 non-null    float64
#  1   blast_furnace_slag             829 non-null    float64
#  2   fly_ash                        829 non-null    float64
#  3   water                          829 non-null    float64
#  4   superplasticizer               829 non-null    float64
#  5   coarse_aggregate               829 non-null    float64
#  6   fine_aggregate                 829 non-null    float64
#  7   age                            829 non-null    int64
#  8   concrete_compressive_strength  829 non-null    float64
# dtypes: float64(8), int64(1)
# memory usage: 58.4 KB

# %%
for feature in dataset.columns:
     print(feature,':',len(dataset[feature].unique()))
# Out:
# cement : 240
# blast_furnace_slag : 173
# fly_ash : 128
# water : 164
# superplasticizer : 96
# coarse_aggregate : 242
# fine_aggregate  : 262
# age : 14
# concrete_compressive_strength : 673

# %%
discrete_features = [feature for feature in dataset.columns if feature == 'age']

# %%
discrete_features
# Out:
# ['age']

# %%
# Copy dataset and set style
data = dataset.copy()
sns.set(style="whitegrid", palette="muted")

# Color palette for bars
colors = sns.color_palette("coolwarm", len(discrete_features))

# Plot each discrete feature's median concrete compressive strength
for i, feature in enumerate(discrete_features):
    plt.figure(figsize=(10, 6))
    
    # Calculate medians for each category in the feature
    median_data = data.groupby(feature)['concrete_compressive_strength'].median()
    
    # Create bar plot with color gradient
    bars = median_data.plot(kind='bar', color=colors[i], edgecolor='black')
    
    # Set labels and title
    plt.xlabel(feature.capitalize(), fontsize=12)
    plt.ylabel('Median Concrete Compressive Strength (MPa)', fontsize=12)
    plt.title(f'Median Concrete Compressive Strength by {feature.capitalize()}', fontsize=14, fontweight='bold')
    
    # Annotate median values on top of each bar
    for bar in bars.patches:
        bars.annotate(format(bar.get_height(), '.2f'),
                      (bar.get_x() + bar.get_width() / 2, bar.get_height()),
                      ha='center', va='center', xytext=(0, 8),
                      textcoords='offset points', fontsize=10, color='black')
    
    plt.show()

# %%
import pandas as pd

# %%
dataset = pd.read_csv('C:\Windows\concrete_data2.csv')

# %%
discrete_features = [feature for feature in dataset.columns if feature == 'age']

# %%
continuous_features = [feature for feature in dataset.columns if feature not in discrete_features]

# %%
continuous_features
# Out:
# ['cement',
#  'blast_furnace_slag',
#  'fly_ash',
#  'water',
#  'superplasticizer',
#  'coarse_aggregate',
#  'fine_aggregate ',
#  'concrete_compressive_strength']

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
data = dataset.copy()

# %%
# Set style
sns.set(style="whitegrid")

# Loop through each continuous feature
for feature in continuous_features:
    plt.figure(figsize=(10, 6))
    
    # Create a boxplot and violin plot for better distribution insight
    sns.violinplot(x=data[feature], y=data['concrete_compressive_strength'], color='lightgreen', inner=None)
    sns.boxplot(x=data[feature], y=data['concrete_compressive_strength'], width=0.2, color='blue', fliersize=6)
    
    # Set labels and title
    plt.xlabel(feature.capitalize(), fontsize=12)
    plt.ylabel('Concrete Compressive Strength (MPa)', fontsize=12)
    plt.title(f'{feature.capitalize()} and Concrete Compressive Strength', fontsize=14, fontweight='bold')
    
    # Show the plot
    plt.show()

# %%
# Copy the dataset
data = dataset.copy()

# Loop through each continuous feature
for feature in continuous_features:
    plt.figure(figsize=(10, 6))
    
    # Group data by the continuous feature and calculate the median of compressive strength
    median_values = data.groupby(feature)['concrete_compressive_strength'].median()
    
    # Plot histogram with KDE
    sns.histplot(median_values, kde=True, color='skyblue', bins=20, stat='density', linewidth=2, edgecolor='black')
    
    
    # Add a vertical line to show the median compressive strength
    plt.axvline(median_values.median(), color='red', linestyle='--', label=f'Median: {median_values.median():.2f} MPa')
    
    # Set labels and title
    plt.xlabel(f'{feature.capitalize()}', fontsize=12)
    plt.ylabel('Density / Count', fontsize=12)
    plt.title(f'Distribution of {feature.capitalize()} and Concrete Compressive Strength', fontsize=14, fontweight='bold')
    
    # Add legend to the plot
    plt.legend()

    # Show the plot
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Copy the dataset
data = dataset.copy()

# Set style
sns.set(style="whitegrid")

# Loop through each continuous feature
for feature in continuous_features:
    # Apply log transformation if feature is greater than 0 (skip if 0 exists in the feature)
    if 0 in data[feature].unique():
        pass
    else:
        data[feature] = np.log(data[feature])
        
        
        # Hexbin plot to show the density of data points
        plt.figure(figsize=(10, 6))
        plt.hexbin(data[feature], data['concrete_compressive_strength'], gridsize=50, cmap='viridis', mincnt=1)
        
        # Add color bar to represent compressive strength density
        plt.colorbar(label='Density')
        
        # Set labels and title
        plt.xlabel(f'Log of {feature.capitalize()}', fontsize=12)
        plt.ylabel('Concrete Compressive Strength (MPa)', fontsize=12)
        plt.title(f'Log Transformation of {feature.capitalize()} vs Concrete Compressive Strength (Hexbin)', fontsize=14, fontweight='bold')
        
        # Show the plot
        plt.show()

# %%
# Copy the dataset
data = dataset.copy()

# Set seaborn style for better aesthetics
sns.set(style="whitegrid")

# Loop through each discrete feature
for feature in discrete_features:
    # Apply log transformation only if the feature does not contain 0 values
    if 0 in data[feature].unique():
        pass
    else:
        data[feature] = np.log(data[feature])
        
        # Create a swarm plot to visualize individual points
        plt.figure(figsize=(8, 6))
        
        
        # Swarm plot
        sns.swarmplot(x=data[feature], color='purple', size=6)
        
        # Add labels and title
        plt.title(f'Swarm Plot of Log-Transformed {feature.capitalize()}', fontsize=14, fontweight='bold')
        plt.xlabel(f'Log of {feature.capitalize()}', fontsize=12)
        plt.ylabel('Values', fontsize=12)
        
        # Show the plot
        plt.show()
# Out:
# C:\Users\KIIT0001\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 61.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
dataset.shape
# Out:
# (829, 9)

# %%
dataset.head()
# Out:
#    cement  blast_furnace_slag  fly_ash  water  superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    coarse_aggregate  fine_aggregate   age  concrete_compressive_strength
# 0            1040.0            676.0   28                          79.99
# 1            1055.0            676.0   28                          61.89
# 2             932.0            594.0  270                          40.27
# 3             932.0            594.0  365                          41.05
# 4             978.4            825.5  360                          44.30

# %%
X = dataset.iloc[:,0:8]
y = dataset.iloc[:,-1]

# %%
X.head()
# Out:
#    cement  blast_furnace_slag  fly_ash  water  superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    coarse_aggregate  fine_aggregate   age
# 0            1040.0            676.0   28
# 1            1055.0            676.0   28
# 2             932.0            594.0  270
# 3             932.0            594.0  365
# 4             978.4            825.5  360

# %%
y.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: concrete_compressive_strength, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.20)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV
linear = LinearRegression()
linear.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
linear_predict = linear.predict(X_test)

# %%
from sklearn.metrics import r2_score
linear_score = r2_score(y_test,linear_predict)
print("Accuracy score for Linear Regression: ",linear_score*100)
# Out:
# Accuracy score for Linear Regression:  62.733522971402444

# %%
from sklearn.linear_model import Ridge
ridge = Ridge()
ridge.fit(X_train,y_train)
# Out:
# Ridge()

# %%
ridge_predict = ridge.predict(X_test)

# %%
ridge_score = r2_score(y_test,ridge_predict)
print("Accuracy score for Ridge Regression: ",ridge_score*100)
# Out:
# Accuracy score for Ridge Regression:  62.733545035154606

# %%
from sklearn.linear_model import Lasso
lasso = Lasso()
lasso.fit(X_train,y_train)
# Out:
# Lasso()

# %%
lasso_predict = lasso.predict(X_test)

# %%
lasso_score = r2_score(y_test,lasso_predict)
print('Accuracy score for Lasso Regression: ',lasso_score*100)
# Out:
# Accuracy score for Lasso Regression:  62.76383264540746

# %%
from sklearn.linear_model import ElasticNet
elastic = ElasticNet()
elastic.fit(X_train,y_train)
# Out:
# ElasticNet()

# %%
elastic_predict = elastic.predict(X_test)

# %%
elastic_score = r2_score(y_test,elastic_predict)
print("Accuracy Score for Elastic Net Regression: ",elastic_score*100)
# Out:
# Accuracy Score for Elastic Net Regression:  62.75989336068866

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor()
knn.fit(X_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
knn_predictt = knn.predict(X_test)

# %%
knn_score = r2_score(y_test,knn_predictt)
print("Accuracy Score of KNN: ",knn_score*100)
# Out:
# Accuracy Score of KNN:  73.38131115875217

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor()
dt.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
dt_predict = dt.predict(X_test)

# %%
dt_score = r2_score(y_test,dt_predict)
print('Accuracy Score for Decision Tree:',dt_score*100)
# Out:
# Accuracy Score for Decision Tree: 88.02924739330254

# %%
from sklearn.svm import SVR
svr = SVR()
svr.fit(X_train,y_train)
# Out:
# SVR()

# %%
svr_predict = svr.predict(X_test)

# %%
svr_score = r2_score(y_test,svr_predict)
print("Accuracy Score for SVR:",svr_score*100)
# Out:
# Accuracy Score for SVR: 27.374847077632314

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rf_predict = rf.predict(X_test)

# %%
rf_score = r2_score(y_test,rf_predict)
print("Accuracy Score for Random Forest Regressor:",rf_score*100)
# Out:
# Accuracy Score for Random Forest Regressor: 92.17878791376506

# %%
from sklearn.ensemble import ExtraTreesRegressor
et = ExtraTreesRegressor()
et.fit(X_train,y_train)
# Out:
# ExtraTreesRegressor()

# %%
et_predict = et.predict(X_test)

# %%
et_score = r2_score(y_test,et_predict)
print("Accuracy Score for ETR:",et_score*100)
# Out:
# Accuracy Score for ETR: 92.26627276526095

# %%
from sklearn.ensemble import AdaBoostRegressor
ad = AdaBoostRegressor()
ad.fit(X_train,y_train)
# Out:
# AdaBoostRegressor()

# %%
ad_predict = ad.predict(X_test)

# %%
ad_score = r2_score(y_test,ad_predict)
print("Accuracy score for Adaboost Regressor:",ad_score*100)
# Out:
# Accuracy score for Adaboost Regressor: 81.63851450446863

# %%
from sklearn.ensemble import GradientBoostingRegressor
gd = GradientBoostingRegressor()
gd.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
gd_predict = gd.predict(X_test)

# %%
gd_score = r2_score(y_test,gd_predict)
print("Accuracy Score for GBR:",gd_score*100)
# Out:
# Accuracy Score for GBR: 92.09570677199711

# %% [markdown]
# <p>© Divyansh Singh 2025</p>
